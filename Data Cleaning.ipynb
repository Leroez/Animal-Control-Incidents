# %%
import pandas as pd
import numpy as np
path = r'/Users/benrivera/Library/Mobile Documents/com~apple~CloudDocs/School/ERM 412/Animal_Control_Incidents.xlsx'

animal_inc = pd.read_excel(path)
animal_inc
# Out:
#         FILE NUMBER INCIDENT DATE INCIDENT TIME DISPATCHED TIME   CALL TAKER  \
# 0         201639027    2016-12-27      15:30:00        16:06:00      UNKNOWN
# 1         201639044    2016-12-28      10:06:00        10:07:00      UNKNOWN
# 2         201639036    2016-12-28      09:03:00        09:03:00      UNKNOWN
# 3         202087899    2020-08-30      13:39:00        00:00:00      UNKNOWN
# 4         201639059    2016-12-28      15:05:00        15:45:00      UNKNOWN
# ...             ...           ...           ...             ...          ...
# 119970   2022110287    2022-11-21      14:07:00        15:09:00      UNKNOWN
# 119971   2022110287    2022-11-21      14:07:00        15:09:00      UNKNOWN
# 119972   2022110391    2022-11-24      05:28:00        06:17:00      UNKNOWN
# 119973   2022110401    2022-11-26      14:31:00        14:33:00  ALLISON E C
# 119974   2022110922    2022-12-07      15:03:00        15:06:00      UNKNOWN
#
# ...

# %% [markdown]
# Data Cleaning

# %%
#This removes missing values
animal_inc = animal_inc.dropna(subset=['SPECIES', 'BREED', "TEMPERMENT"])
#reseting the index
animal_inc2 = animal_inc.reset_index(drop=True)
#drops certain columns
animal_inc2 = animal_inc2.drop(['COLLAR', 'VACCINATION NUMBER', 'COLLAR COLOR', 'AGE', "VACCINATION DATE", "PET NAME"], axis = 1)

animal_inc2
# Out:
#        FILE NUMBER INCIDENT DATE INCIDENT TIME DISPATCHED TIME   CALL TAKER  \
# 0        201639027    2016-12-27      15:30:00        16:06:00      UNKNOWN
# 1        201639044    2016-12-28      10:06:00        10:07:00      UNKNOWN
# 2        201639036    2016-12-28      09:03:00        09:03:00      UNKNOWN
# 3        201639059    2016-12-28      15:05:00        15:45:00      UNKNOWN
# 4        201639043    2016-12-28      10:03:00        10:10:00      UNKNOWN
# ...            ...           ...           ...             ...          ...
# 59835   2022110287    2022-11-21      14:07:00        15:09:00      UNKNOWN
# 59836   2022110287    2022-11-21      14:07:00        15:09:00      UNKNOWN
# 59837   2022110391    2022-11-24      05:28:00        06:17:00      UNKNOWN
# 59838   2022110401    2022-11-26      14:31:00        14:33:00  ALLISON E C
# 59839   2022110922    2022-12-07      15:03:00        15:06:00      UNKNOWN
#
# ...

# %%
animal_inc2 =animal_inc2.drop(animal_inc2[animal_inc2["TEMPERMENT"] == "UNKNOWN"].index)

animal_inc2 =animal_inc2.drop(animal_inc2[animal_inc2["SPECIES"] == "UNKNOWN"].index)

animal_inc2 =animal_inc2.drop(animal_inc2[animal_inc2["SEX"] == "U"].index)


animal_inc2 = animal_inc2.reset_index(drop=True)


animal_inc2.TEMPERMENT
# Out:
# 0        FRIENDLY
# 1          NORMAL
# 2        FRIENDLY
# 3        FRIENDLY
# 4        FRIENDLY
#            ...
# 43065    FRIENDLY
# 43066    FRIENDLY
# 43067    FRIENDLY
# 43068     NERVOUS
# 43069    FRIENDLY
# Name: TEMPERMENT, Length: 43070, dtype: object

# %%
animal_inc2
# Out:
#        FILE NUMBER INCIDENT DATE INCIDENT TIME DISPATCHED TIME   CALL TAKER  \
# 0        201639027    2016-12-27      15:30:00        16:06:00      UNKNOWN
# 1        201639059    2016-12-28      15:05:00        15:45:00      UNKNOWN
# 2        201639043    2016-12-28      10:03:00        10:10:00      UNKNOWN
# 3        201639047    2016-12-28      10:59:00        11:00:00      UNKNOWN
# 4        201630733    2016-06-06      14:06:00        00:00:00      UNKNOWN
# ...            ...           ...           ...             ...          ...
# 43065   2022110175    2022-11-18      08:18:00        08:22:00      UNKNOWN
# 43066   2022110287    2022-11-21      14:07:00        15:09:00      UNKNOWN
# 43067   2022110287    2022-11-21      14:07:00        15:09:00      UNKNOWN
# 43068   2022110401    2022-11-26      14:31:00        14:33:00  ALLISON E C
# 43069   2022110922    2022-12-07      15:03:00        15:06:00      UNKNOWN
#
# ...

# %%
animal_inc2.to_excel(r'/Users/benrivera/Library/Mobile Documents/com~apple~CloudDocs/School/ERM 412/Animal_Control_Incidents.xlsx', index= False)
